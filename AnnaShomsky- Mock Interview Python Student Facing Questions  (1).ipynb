# %% [markdown]
# <h3> Mock Interview Python Screening test </h3>

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
dataframe = pd.read_csv("adult_census_data.csv")

# %%
dataframe.head()
dataframe.columns
#column names have an extra space in front
# Out:
# Index(['39', ' State-gov', ' 77516', ' Bachelors', ' 13', ' Never-married',
#        ' Adm-clerical', ' Not-in-family', ' White', ' Male', ' 2174', ' 0',
#        ' 40', ' United-States', ' <=50K'],
#       dtype='object')

# %% [markdown]
# <b> Q1. After importing the adult_census_data.csv file, please filter this to include only the following criteria: </b>
# <p>
#
# <li> State-Gov</li>
# <li> Bachelors </li>
# <li> Never-Married </li>
# <li> Adm-Clerical </li>
# <li> Not-in-familiy </li>
# <li> White </li>
# <li> Male </li>
# <li> United States </li>
# <li> <=50K </li>
#
# <b> Feel free to any method to complete this tasks. However, we recommend you use either list filtering [], or .loc to complete this task.</b>

# %% [markdown]
# <b> Put your code below </b>

# %%
census_data= dataframe[[" State-gov", " Bachelors", " Never-married", " Adm-clerical", ' Not-in-family', " White", " Male",' United-States', " <=50K"]]
census_data.head(30)
# Out:
#             State-gov      Bachelors           Never-married  \
# 0    Self-emp-not-inc      Bachelors      Married-civ-spouse
# 1             Private        HS-grad                Divorced
# 2             Private           11th      Married-civ-spouse
# 3             Private      Bachelors      Married-civ-spouse
# 4             Private        Masters      Married-civ-spouse
# 5             Private            9th   Married-spouse-absent
# 6    Self-emp-not-inc        HS-grad      Married-civ-spouse
# 7             Private        Masters           Never-married
# 8             Private      Bachelors      Married-civ-spouse
# 9             Private   Some-college      Married-civ-spouse
# 10          State-gov      Bachelors      Married-civ-spouse
# 11            Private      Bachelors           Never-married
# 12            Private     Assoc-acdm           Never-married
# 13            Private      Assoc-voc      Married-civ-spouse
# 14            Private        7th-8th      Married-civ-spouse
# 15   Self-emp-not-inc        HS-grad           Never-married
# 16            Private        HS-grad           Never-married
# 17            Private           11th      Married-civ-spouse
# 18   Self-emp-not-inc        Masters                Divorced
# 19            Private      Doctorate      Married-civ-spouse
# 20            Private        HS-grad               Separated
# 21        Federal-gov            9th      Married-civ-spouse
# 22            Private           11th      Married-civ-spouse
# 23            Private        HS-grad                Divorced
# 24          Local-gov      Bachelors      Married-civ-spouse
# 25            Private        HS-grad           Never-married
# 26                  ?   Some-college      Married-civ-spouse
# 27            Private        HS-grad                Divorced
# 28            Private        HS-grad      Married-civ-spouse
# 29          Local-gov     Assoc-acdm           Never-married
#
#           Adm-clerical   Not-in-family                White     Male  \
# 0      Exec-managerial         Husband                White     Male
# 1    Handlers-cleaners   Not-in-family                White     Male
# 2    Handlers-cleaners         Husband                Black     Male
# 3       Prof-specialty            Wife                Black   Female
# 4      Exec-managerial            Wife                White   Female
# 5        Other-service   Not-in-family                Black   Female
# 6      Exec-managerial         Husband                White     Male
# 7       Prof-specialty   Not-in-family                White   Female
# 8      Exec-managerial         Husband                White     Male
# 9      Exec-managerial         Husband                Black     Male
# 10      Prof-specialty         Husband   Asian-Pac-Islander     Male
# 11        Adm-clerical       Own-child                White   Female
# 12               Sales   Not-in-family                Black     Male
# 13        Craft-repair         Husband   Asian-Pac-Islander     Male
# 14    Transport-moving         Husband   Amer-Indian-Eskimo     Male
# 15     Farming-fishing       Own-child                White     Male
# 16   Machine-op-inspct       Unmarried                White     Male
# 17               Sales         Husband                White     Male
# 18     Exec-managerial       Unmarried                White   Female
# 19      Prof-specialty         Husband                White     Male
# 20       Other-service       Unmarried                Black   Female
# 21     Farming-fishing         Husband                Black     Male
# 22    Transport-moving         Husband                White     Male
# 23        Tech-support       Unmarried                White   Female
# 24        Tech-support         Husband                White     Male
# 25        Craft-repair       Own-child                White     Male
# 26                   ?         Husband   Asian-Pac-Islander     Male
# 27     Exec-managerial   Not-in-family                White     Male
# 28        Craft-repair         Husband                White     Male
# 29     Protective-serv   Not-in-family                White     Male
#
#      United-States   <=50K
# 0    United-States   <=50K
# 1    United-States   <=50K
# 2    United-States   <=50K
# 3             Cuba   <=50K
# 4    United-States   <=50K
# 5          Jamaica   <=50K
# 6    United-States    >50K
# 7    United-States    >50K
# 8    United-States    >50K
# 9    United-States    >50K
# 10           India    >50K
# 11   United-States   <=50K
# 12   United-States   <=50K
# 13               ?    >50K
# 14          Mexico   <=50K
# 15   United-States   <=50K
# 16   United-States   <=50K
# 17   United-States   <=50K
# 18   United-States    >50K
# 19   United-States    >50K
# 20   United-States   <=50K
# 21   United-States   <=50K
# 22   United-States   <=50K
# 23   United-States   <=50K
# 24   United-States    >50K
# 25   United-States   <=50K
# 26           South    >50K
# 27   United-States   <=50K
# 28   United-States   <=50K
# 29   United-States   <=50K

# %% [markdown]
# <b> Currently, the dataframe you are using has the following column names: </b>
#
# [' State-gov', ' Bachelors', ' Never-married',
#        ' Adm-clerical', ' Not-in-family', ' White', ' Male', ' United-States', ' <=50K']
#
#
# <b> Q2. Please re-name all the newly filtered columns in the pandas DataFrame to the following: </b>
#
# Employment Type, Degree Status, Marriage-Status, Job-Role, Family-Role, Ethnicity, Gender, Country, Earnings
#
# E.g. State-Gov becomes Employment Type, Bachelors becomes Degree Status, etc.

# %% [markdown]
# <b> Put your code below </b>

# %%
census_data= census_data.rename(columns = {" State-gov":"Employment Type"," Bachelors":"Degree Status", " Never-married": "Marriage-Status", " Adm-clerical" : "Job-Role", " Not-in-family":"Family-Role", " White":"Ethnicity", " Male":"Gender",' United-States': "Country", " <=50K":"Earnings" })
census_data.head(10)
# Out:
#      Employment Type  Degree Status         Marriage-Status  \
# 0   Self-emp-not-inc      Bachelors      Married-civ-spouse
# 1            Private        HS-grad                Divorced
# 2            Private           11th      Married-civ-spouse
# 3            Private      Bachelors      Married-civ-spouse
# 4            Private        Masters      Married-civ-spouse
# 5            Private            9th   Married-spouse-absent
# 6   Self-emp-not-inc        HS-grad      Married-civ-spouse
# 7            Private        Masters           Never-married
# 8            Private      Bachelors      Married-civ-spouse
# 9            Private   Some-college      Married-civ-spouse
#
#              Job-Role     Family-Role Ethnicity   Gender         Country  \
# 0     Exec-managerial         Husband     White     Male   United-States
# 1   Handlers-cleaners   Not-in-family     White     Male   United-States
# 2   Handlers-cleaners         Husband     Black     Male   United-States
# 3      Prof-specialty            Wife     Black   Female            Cuba
# 4     Exec-managerial            Wife     White   Female   United-States
# 5       Other-service   Not-in-family     Black   Female         Jamaica
# 6     Exec-managerial         Husband     White     Male   United-States
# 7      Prof-specialty   Not-in-family     White   Female   United-States
# 8     Exec-managerial         Husband     White     Male   United-States
# 9     Exec-managerial         Husband     Black     Male   United-States
#
#   Earnings
# 0    <=50K
# 1    <=50K
# 2    <=50K
# 3    <=50K
# 4    <=50K
# 5    <=50K
# 6     >50K
# 7     >50K
# 8     >50K
# 9     >50K

# %% [markdown]
# <b> Q3. The Job Role Columns holds the job information for each individual in this census snapshot. Using this column, create a Bar Chart that shows the count of 'Unique' Jobs per Job Group in the "Job-Role" Column in ascending order, as per the provided image below </b>

# %% [markdown]
# <b> Put your code below </b>

# %%
jobs= census_data["Job-Role"].value_counts()
jobs.plot(kind= "bar", title= "Number of Workers per Job Category")
# Out:
# <AxesSubplot:title={'center':'Number of Workers per Job Category'}>

# %% [markdown]
# <b> Q4. Please create two bar plots as per below that show:
#
#     1) The number of individuals who have a High School Graduate Diploma AND earn <=50K in the United States
#     2) The number of individuals who have a High School Graduate Diploma AND earn >50K in the United States
#
# Please note you will be looking specifically at the *Job Role* column

# %% [markdown]
# <b> Put Your Code Below </b>

# %%
jobs_more_than_HS= census_data.loc[(census_data["Degree Status"]==" HS-grad" ) | (census_data["Degree Status"]==" Masters") | (census_data["Degree Status"]==" Bachelors") | (census_data["Degree Status"]==" Some-college") | (census_data["Degree Status"]==" Doctorate") | (census_data["Degree Status"]==" Assoc-acdm") | (census_data["Degree Status"]==" Assoc-voc")]
jobs_more_than_HS.head()
# Out:
#      Employment Type Degree Status      Marriage-Status            Job-Role  \
# 0   Self-emp-not-inc     Bachelors   Married-civ-spouse     Exec-managerial
# 1            Private       HS-grad             Divorced   Handlers-cleaners
# 3            Private     Bachelors   Married-civ-spouse      Prof-specialty
# 4            Private       Masters   Married-civ-spouse     Exec-managerial
# 6   Self-emp-not-inc       HS-grad   Married-civ-spouse     Exec-managerial
#
#       Family-Role Ethnicity   Gender         Country Earnings
# 0         Husband     White     Male   United-States    <=50K
# 1   Not-in-family     White     Male   United-States    <=50K
# 3            Wife     Black   Female            Cuba    <=50K
# 4            Wife     White   Female   United-States    <=50K
# 6         Husband     White     Male   United-States     >50K

# %%
jobs_less_than_50k=jobs_more_than_HS.loc[(jobs_more_than_HS["Earnings"]==" <=50K")]
jobs_less_than_50k.head()
# Out:
#       Employment Type Degree Status      Marriage-Status            Job-Role  \
# 0    Self-emp-not-inc     Bachelors   Married-civ-spouse     Exec-managerial
# 1             Private       HS-grad             Divorced   Handlers-cleaners
# 3             Private     Bachelors   Married-civ-spouse      Prof-specialty
# 4             Private       Masters   Married-civ-spouse     Exec-managerial
# 11            Private     Bachelors        Never-married        Adm-clerical
#
#        Family-Role Ethnicity   Gender         Country Earnings
# 0          Husband     White     Male   United-States    <=50K
# 1    Not-in-family     White     Male   United-States    <=50K
# 3             Wife     Black   Female            Cuba    <=50K
# 4             Wife     White   Female   United-States    <=50K
# 11       Own-child     White   Female   United-States    <=50K

# %%
 
numberjobs_less_than_fiftyk=jobs_less_than_50k["Job-Role"].value_counts()
numberjobs_less_than_fiftyk.plot(kind="bar", title= "Number of Workers with a HS Diploma per Job Category Earning Less Than 50K")
# Out:
# <AxesSubplot:title={'center':'Number of Workers with a HS Diploma per Job Category Earning Less Than 50K'}>

# %%
jobs_more_than_50k=jobs_more_than_HS.loc[(jobs_more_than_HS["Earnings"]==" >50K")]
jobs_more_than_50k.head()
# Out:
#       Employment Type  Degree Status      Marriage-Status          Job-Role  \
# 6    Self-emp-not-inc        HS-grad   Married-civ-spouse   Exec-managerial
# 7             Private        Masters        Never-married    Prof-specialty
# 8             Private      Bachelors   Married-civ-spouse   Exec-managerial
# 9             Private   Some-college   Married-civ-spouse   Exec-managerial
# 10          State-gov      Bachelors   Married-civ-spouse    Prof-specialty
#
#        Family-Role            Ethnicity   Gender         Country Earnings
# 6          Husband                White     Male   United-States     >50K
# 7    Not-in-family                White   Female   United-States     >50K
# 8          Husband                White     Male   United-States     >50K
# 9          Husband                Black     Male   United-States     >50K
# 10         Husband   Asian-Pac-Islander     Male           India     >50K

# %%
numberjobs_greater_than_fiftyk=jobs_more_than_50k["Job-Role"].value_counts()
numberjobs_greater_than_fiftyk.plot(kind="bar", figsize=(10,8), title= "Number of Workers with at least a HS Diploma per Job Category Earning More Than 50K")
# Out:
# <AxesSubplot:title={'center':'Number of Workers with at least a HS Diploma per Job Category Earning More Than 50K'}>

# %% [markdown]
# <H2> Challenge Question </H2>
#
# <b> Q5. Which Job Role has the highest <i> proportion </i> of individuals who earn >50K? </b>

# %% [markdown]
# <b> Put your code below </b>

# %%
jobs_and_earnings= census_data[["Job-Role", "Earnings"]]
jobs_and_earnings2=jobs_and_earnings.groupby(["Job-Role", "Earnings"])["Earnings"].count()

jobs4= jobs_and_earnings2.to_frame(name='count_of_jobs')
jobs4
# Out:
#                              count_of_jobs
# Job-Role           Earnings
#  ?                  <=50K             1652
#                     >50K               191
#  Adm-clerical       <=50K             3262
#                     >50K               507
#  Armed-Forces       <=50K                8
#                     >50K                 1
#  Craft-repair       <=50K             3170
#                     >50K               929
#  Exec-managerial    <=50K             2098
#                     >50K              1968
#  Farming-fishing    <=50K              879
#                     >50K               115
#  Handlers-cleaners  <=50K             1284
#                     >50K                86
#  Machine-op-inspct  <=50K             1752
#                     >50K               250
#  Other-service      <=50K             3158
#                     >50K               137
#  Priv-house-serv    <=50K              148
#                     >50K                 1
#  Prof-specialty     <=50K             2281
#                     >50K              1859
#  Protective-serv    <=50K              438
#                     >50K               211
#  Sales              <=50K             2667
#                     >50K               983
#  Tech-support       <=50K              645
#                     >50K               283
#  Transport-moving   <=50K             1277
#                     >50K               320

# %%
import numpy as np

# %%
jobs5=jobs4.reset_index()

# %%
table = pd.pivot_table(jobs5, values='count_of_jobs',index= ["Job-Role"],
                     columns=['Earnings'], aggfunc=np.sum)
table
# Out:
# Earnings             <=50K   >50K
# Job-Role
#  ?                    1652    191
#  Adm-clerical         3262    507
#  Armed-Forces            8      1
#  Craft-repair         3170    929
#  Exec-managerial      2098   1968
#  Farming-fishing       879    115
#  Handlers-cleaners    1284     86
#  Machine-op-inspct    1752    250
#  Other-service        3158    137
#  Priv-house-serv       148      1
#  Prof-specialty       2281   1859
#  Protective-serv       438    211
#  Sales                2667    983
#  Tech-support          645    283
#  Transport-moving     1277    320

# %%
table2=table.reset_index()

# %%
table3= table2.rename(columns={" <=50K":"less_than_fiftyk", " >50K":"greater_than_fiftyk"})
table3["ratio"]=table3["greater_than_fiftyk"]/table3["less_than_fiftyk"]
table3
# Out:
# Earnings            Job-Role  less_than_fiftyk  greater_than_fiftyk     ratio
# 0                          ?              1652                  191  0.115617
# 1               Adm-clerical              3262                  507  0.155426
# 2               Armed-Forces                 8                    1  0.125000
# 3               Craft-repair              3170                  929  0.293060
# 4            Exec-managerial              2098                 1968  0.938036
# 5            Farming-fishing               879                  115  0.130830
# 6          Handlers-cleaners              1284                   86  0.066978
# 7          Machine-op-inspct              1752                  250  0.142694
# 8              Other-service              3158                  137  0.043382
# 9            Priv-house-serv               148                    1  0.006757
# 10            Prof-specialty              2281                 1859  0.814993
# 11           Protective-serv               438                  211  0.481735
# 12                     Sales              2667                  983  0.368579
# 13              Tech-support               645                  283  0.438760
# 14          Transport-moving              1277                  320  0.250587

# %%
table3.loc[table3["ratio"].idxmax()]
# Out:
# Earnings
# Job-Role                Exec-managerial
# less_than_fiftyk                   2098
# greater_than_fiftyk                1968
# ratio                          0.938036
# Name: 4, dtype: object

# %% [markdown]
#  ### The job category with the highest proportion of higher salaries is Exec-managerial with a ratio of .938. Note that in every job category, there are more people who earn less than 50k than there are people who earn more than 50k.
